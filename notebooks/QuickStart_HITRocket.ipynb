# %% [markdown]
# # HIT-Rocket Quick Start Tutorial
#
# This notebook demonstrates how to use the `HITRocketTransform` for efficient time series classification.
# We will use the **GunPoint** dataset as a simple example.

# %%
import sys
import os
import numpy as np
import pandas as pd
from sklearn.linear_model import RidgeClassifierCV
from sklearn.metrics import accuracy_score

# Add src to path to import HITRocket
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../src")))

# 这里暂时注释，等下一步 src 填充好后即可运行
# from hitrocket import HITRocketTransform 
# from utils import load_data

# %% [markdown]
# ## 1. Load Data
# Loading sample data from `../data/sample_data`

# %%
dataset_name = "GunPoint"
data_path = "../data/sample_data"

print(f"Loading {dataset_name}...")
# X_train, y_train, X_test, y_test = load_data(data_path, dataset_name)
# print(f"Train shape: {X_train.shape}")

# %% [markdown]
# ## 2. Initialize & Transform
# Using HIT-Rocket to transform time series into features.

# %%
# model = HITRocketTransform(dilations=[1, 2, 4, 8, 16], bias_quantiles=[0.25, 0.5, 0.75])
# X_train_feats = model.fit_transform(X_train)
# X_test_feats = model.transform(X_test)

# print(f"Feature shape: {X_train_feats.shape}")

# %% [markdown]
# ## 3. Classification
# Using a simple Ridge Classifier.

# %%
# clf = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10))
# clf.fit(X_train_feats, y_train)
# pred = clf.predict(X_test_feats)
# print(f"Accuracy: {accuracy_score(y_test, pred):.4f}")
